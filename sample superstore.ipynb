# %% [markdown]
# ## NAME - ABHAS KUSHWAHA

# %% [markdown]
#  EMAIL- abhaskushwaha.ak@gmail.com

# %% [markdown]
# COURSE- BTECH (INFORMATION TECNOLOGY)

# %% [markdown]
# SEMESTER - 6TH

# %% [markdown]
# UNIVERSITY - MEDI-CAPS UNIVERSITY ,INDORE ,M.P.,INDIA

# %% [markdown]
# LINKEDIN -https://www.linkedin.com/in/abhas-kushwaha-690ba6189/

# %% [markdown]
#    ##        DATA SCIENCE AND BUSINESS ANALYTICS TASK - 3 ##

# %% [markdown]
# ##  EXPLORATORY DATA ANALYSIS ON DATASET SAMPLESUPERSTORE

# %% [markdown]
# ## IMPORTING DATASET

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
ss= pd.read_csv("E:\python\SampleSuperstore.csv")

# %%
ss.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ## DESCRIPTIVE ANALYSIS

# %% [markdown]
# ### SIZE OF DATASET

# %%
ss.size
# Out:
# 129922

# %% [markdown]
# ### DIMENSIONALITY OF DATASET

# %%
print(ss.shape) # To get the dimensionality of the dataframe
print(ss.ndim) # The number of axes / array dimensions
# Out:
# (9994, 13)
# 2

# %% [markdown]
# ### SUMMARY OF DATASET

# %%
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ### DESCRIPTIVE ANALYSIS USING DESCRIBE FUNCTION

# %%
ss.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### To check whether data contains null value or not

# %%
ss.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### To check whether data contains duplicate values or not

# %%
ss.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ### To drop data containing duplicate values

# %%
ss.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### To check different types of data  Country contains

# %%
ss['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %% [markdown]
# ### To drop country and and postal code

# %%
ss=ss.drop(['Country'],axis=1)
ss=ss.drop(['Postal Code'],axis=1)

# %% [markdown]
# ### UPDATED DATA

# %%
ss.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ### SIZE OF UPDATED DATASET

# %%
ss.size
# Out:
# 109934

# %% [markdown]
# ### DIMENSIONALITY OF UPDATED DATASET

# %%
print(ss.shape) # To get the dimensionality of the dataframe
print(ss.ndim) # The number of axes / array dimensions
# Out:
# (9994, 11)
# 2

# %% [markdown]
# ### DATATYPES OF UPDATED DATASET

# %%
ss.dtypes
# Out:
# Ship Mode        object
# Segment          object
# City             object
# State            object
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ### SUMMARY OF UPDATED DATASET

# %%
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 859.0+ KB

# %% [markdown]
# ### DESCRIPTIVE ANALYSIS USING DESCRIBE FUNCTION

# %%
ss.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### CORRELATION BETWEEN VARIABLES

# %%
ss.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ### VISUALLY EXPLORING USING HEATMAP

# %%
f, ax = plt.subplots(figsize=((16,9)))
corr = ss.corr()
sns.heatmap(corr,annot=True,linewidths=.5, cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax)

# %% [markdown]
# ### EXPLORING DATA USING COUNTPLOT

# %% [markdown]
# ### CATEGORY

# %%
sns.countplot(x='Category',data=ss)

# %% [markdown]
# ### SUB-CATEGORY

# %%
plt.subplots(figsize=((16,9)))
sns.countplot(x='Sub-Category',data=ss)

# %% [markdown]
# ### REGION

# %%
sns.countplot(x='Region',data=ss)

# %% [markdown]
# ### SEGMENT

# %%
sns.countplot(x='Segment',data=ss)

# %% [markdown]
# ### SHIP MODE

# %%
sns.countplot(x='Ship Mode',data=ss)

# %% [markdown]
# ### PROFIT ANALYSIS

# %% [markdown]
# ### Computing top categories in terms of sales from first 100 observations

# %%
category_s=ss.groupby('Category').Sales.sum().nlargest(n=100)
category_p=ss.groupby('Category').Profit.sum().nlargest(n=100)

# %% [markdown]
# ### PROFIT ANALYSIS OF CATEGORY

# %%
plt.style.use('seaborn')
category_s.plot(kind='bar',figsize=(12,6),fontsize =14,legend=True)
category_p.plot(kind='bar',figsize=(12,6),fontsize =14,color='orange',legend=True)
plt.xlabel('Category',fontsize=15)
plt.ylabel('Total Sales/Profits',fontsize=15)
plt.title('Top Category Sales vs Profits',fontsize=15)
plt.show()

# %% [markdown]
# ### PROFIT ANALYSIS OF SUB-CATEGORY

# %%
category_s=ss.groupby('Sub-Category').Sales.sum().nlargest(n=100)
category_p=ss.groupby('Sub-Category').Profit.sum().nlargest(n=100)
plt.style.use('seaborn')
category_s.plot(kind='bar',figsize=(12,6),fontsize =14,legend=True)
category_p.plot(kind='bar',figsize=(12,6),fontsize =14,color='orange',legend=True)
plt.xlabel('Sub-Category',fontsize=15)
plt.ylabel('Total Sales/Profits',fontsize=15)
plt.title('Top Sub-Category Sales vs Profits',fontsize=15)
plt.show()

# %% [markdown]
# ### PROFIT ANALYSIS OF REGION

# %%
plt.figure(figsize=(6,6))
plt.title('Region')
plt.pie(ss['Region'].value_counts(),labels=ss['Region'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### PROFIT ANALYSIS OF STATES

# %%
category_s=ss.groupby('State').Sales.sum().nlargest(n=100)
category_p=ss.groupby('State').Profit.sum().nlargest(n=100)
plt.style.use('seaborn')
category_s.plot(kind='bar',figsize=(12,6),fontsize =14,legend=True)
category_p.plot(kind='bar',figsize=(12,6),fontsize =14,color='orange',legend=True)
plt.xlabel('States',fontsize=15)
plt.ylabel('Total Sales/Profits',fontsize=15)
plt.title('Top States Sales vs Profits',fontsize=15)
plt.show()

# %% [markdown]
# ### PROFIT ANALYSIS OF SEGMENT

# %%
category_s=ss.groupby('Segment').Sales.sum().nlargest(n=100)
category_p=ss.groupby('Segment').Profit.sum().nlargest(n=100)
plt.style.use('seaborn')
category_s.plot(kind='bar',figsize=(12,6),fontsize =14,legend=True)
category_p.plot(kind='bar',figsize=(12,6),fontsize =14,color='orange',legend=True)
plt.xlabel('Segment',fontsize=15)
plt.ylabel('Total Sales/Profits',fontsize=15)
plt.title('Top Segment Sales vs Profits',fontsize=15)
plt.show()

# %% [markdown]
# ### PROFIT ANALYSIS OF SHIP-MODE

# %%
category_s=ss.groupby('Ship Mode').Sales.sum().nlargest(n=100)
category_p=ss.groupby('Ship Mode').Profit.sum().nlargest(n=100)
plt.style.use('seaborn')
category_s.plot(kind='bar',figsize=(12,6),fontsize =14,legend=True)
category_p.plot(kind='bar',figsize=(12,6),fontsize =14,color='orange',legend=True)
plt.xlabel('Ship Mode',fontsize=15)
plt.ylabel('Total Sales/Profits',fontsize=15)
plt.title('Top Ship Mode Sales vs Profits',fontsize=15)
plt.show()

# %% [markdown]
# ### RELATIONSHIP BETWEEN DISCOUNT AND PROFIT

# %%
plt.figure(figsize=(16,9))
sns.lineplot(ss['Discount'],ss['Profit'],data=ss,color='green')

# %% [markdown]
# # INSIGHTS DERIVED FROM ABOVE EDA

# %% [markdown]
# 1. Profit and Discount show very weak and negative relationship.That should be kept in mind before taking another decision related to business

# %% [markdown]
# 2. Considering the sales of sub-categories , sales of tables should be minimized

# %% [markdown]
# 3.Improvement should be made for same day shipment mode

# %% [markdown]
# 4. We should concentrate on the states like 'New York' and 'California' to make more profits.

# %% [markdown]
# 5. Company is facing loss in states like 'Texas','Ohio','Pennysylvenia','Illionis','North Carolina','Colorado'

# %% [markdown]
#  6. We need to work more on furniture category of bussiness

# %% [markdown]
# 7. The profit of bookcase and tables are in negative ,company is facing loss beacuse of these two products.

# %% [markdown]
#  8. Sales of copier and mobile can be increased to maximise profits
